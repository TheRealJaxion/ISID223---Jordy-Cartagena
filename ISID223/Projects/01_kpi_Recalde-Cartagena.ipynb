# %% [markdown]
# # Taller: Creación y Visualización de KPIs
# - Nombres: Ariel Recalde, Jordy Cartagena
# - GR1CD
# - 22 de Mayo de 2026
#
# ## Objetivos de Aprendizaje
#
# * **De Conocimientos:** Evidenciar cómo un Sistema de Información Gerencial (MIS) sintetiza los datos atómicos y transaccionales de un *Transaction Processing System* (TPS) en un repositorio común para generar reportes estructurados que apoyen la toma de decisiones medibles (KPIs).
# * **De Destrezas:** Aplicar el enfoque de sistemas para resolver un problema de TI organizacional, mapeando el flujo desde los *Data Items* elementales hasta el *Knowledge* estratégico.
# * **De Valores y Actitudes:** Experimentar el trabajo en equipo a través del codiseño de una solución de software empresarial y la presentación de argumentos técnicos efectivos.
#
# ## Introducción (Enlace Arquitectónico)
#
# Recordemos que los **Sistemas de Procesamiento de Transacciones (TPS)** se encargan de monitorear, recolectar, almacenar y procesar los datos de las operaciones básicas diarias de la organización (datos en tiempo real, de alto volumen y nivel atómico).
#
# Por otro lado, los **Sistemas de Información Gerencial (MIS)** acceden a estos repositorios comunes de datos transaccionales para resumirlos, procesarlos y presentar reportes estructurados (como indicadores clave de rendimiento o **KPIs**) orientados a mandos medios y gerenciales. Nuestro objetivo de hoy es construir la capa del MIS que consume los datos del TPS que ustedes ya desarrollaron.

# %% [markdown]
# ## 1: Construir Conocimiento desde los Datos
#
# En esta fase inicial, cada equipo de trabajo debe formalizar el ciclo de vida de la información que va a visualizar, e identificar **3 KPIs** de su proyecto, para construir en esta actividad. Para los **3 KPIs** seleccionados, completen la siguiente matriz conceptual en su informe:
#
# 1. **Data Items (Datos Crudos):** Describan los hechos elementales almacenados en su TPS sin organizar (ej. marcas de tiempo, IDs de transacciones, valores numéricos crudos).
# 2. **Information (Información Organizada):** Expliquen cómo la agregación o procesamiento matemático de esos datos les asigna un significado y un valor contextual para el negocio.
# 3. **Knowledge (Conocimiento Aplicado):** Describan la lógica o experiencia acumulada que determina qué decisión operativa o táctica se tomará según el comportamiento del KPI (ej. si el indicador supera un umbral de alerta, qué proceso se dispara).
#
# > **Aviso de Calidad de Datos:** Al diseñar su flujo, recuerden el principio **GIGO (*Garbage In, Garbage Out*)**. Si los datos capturados originalmente por su TPS contienen inconsistencias o faltas de integridad, el reporte generado por el MIS carecerá de confiabilidad y validez para la toma de decisiones.

# %% [markdown]
# # Matriz KPIs - Biblioteca digital
#
# ### KPI 1 libros mas solicitados
#
# | Componente | Aplicación en el proyecto |
# | :--- | :--- |
# | Datos Crudos | Atributo idPrestamo (int), estado (String con valores "ACTIVO", "DEVUELTO", o "VENCIDO") y la propiedad activo (boolean) de la cuenta de usuario.
# | Informacion Organizada |El MIS accede al histórico consolidado del archivo de transacciones. Utilizando Python (Pandas), cuenta el número total de registros históricos y filtra simultáneamente las filas donde el campo estado == "VENCIDO".
# | Conocimiento Aplicado | Lógica o regla de negocio: Si la Tasa de Morosidad supera el umbral máximo tolerable del 12%, el sistema activa una bandera táctica. La gerencia instruye al sistema disparar el método transaccional obtenerPrestamosProximosAVencer(3) de la clase PrestamoControl para despachar notificaciones proactivas automatizadas por correo electrónico a los estudiantes antes de que caigan en estado de infracción, mitigando el estancamiento del inventario físico/digital.
# ---
# ### KPI 2: Severidad del Retraso de Devoluciones
# | Componente | Aplicación en el proyecto |
# | :--- | :--- |
# | Datos Crudos | Atributo idPrestamo (int), fechaDevolucionEsperada (LocalDate), fechaDevolucionReal (LocalDate), y el resultado entero devuelto por la lógica del método getDiasVencidos().
# | Informacion Organizada |El componente del MIS filtra exclusivamente aquellas transacciones cuyo estado ha cambiado a "DEVUELTO" pero que registraron una penalización de tiempo. Se calcula la diferencia neta en días a través del equivalente matemático de ChronoUnit.DAYS.between() y se aplica la media aritmética (.mean()) sobre el acumulado del mes para obtener el indicador macro del retraso promedio del usuario.
# | Conocimiento Aplicado |Si la media global de días vencidos escala por encima de los 5 días, denota un abuso sistemático de las reservas de la biblioteca. Como acción correctiva inmediata, la administración ejecuta una política restrictiva en el TPS: altera dinámicamente el parámetro maxLibrosPrestamo en el objeto Usuario (reduciéndolo temporalmente de 3 a 1) o invoca el bloqueo del método puedePedirLibros() para usuarios con reincidencia cruda.
# ---
# ### KPI 3 Densidad de Demanda por Categoría del Catálogo
# | Componente | Aplicación en el proyecto |
# | :--- | :--- |
# | Datos Crudos |Atributo idPrestamo (int), código referencial del libro isbn (String), y el atributo descriptivo categoria (String) mapeado desde el objeto Libro.
# | Informacion Organizada |El script de análisis extrae el flujo transaccional de la biblioteca. Realiza una operación de fusión o cruzamiento lógico de datos (join) entre la colección de registros de préstamos y la tabla maestra de libros a través del campo común isbn. Posteriormente, ejecuta una función de agrupación por etiquetas (groupby('categoria')) y cuenta el volumen de ocurrencias (count()) para transformar elementos atómicos en un ranking porcentual de uso por área del conocimiento.
# | Conocimiento Aplicado |Lógica o regla de negocio: Si una categoría académica (ej. "Ingeniería de Sistemas" o "Estructuras de Datos") abarca más del 55% de la densidad de solicitudes mensuales, la gerencia toma la decisión estratégica de reasignar fondos presupuestarios para expandir la cantidadTotal de ejemplares disponibles en el catálogo. Si un área se sitúa persistentemente por debajo del 3%, se suspenden adquisiciones de esa categoría para optimizar la infraestructura de almacenamiento
# ---

# %% [markdown]
# ## 2: Mapeo de Atributos y Boceto de Interfaz
#
# Antes de proceder a la escritura de código, es fundamental realizar el diseño lógico y visual de la solución.
#
# ### 2.1 Mapeo en el Esquema de Base de Datos
# Identifiquen en las tablas CSV de la base de datos de su TPS cuáles son las entidades, y atributos (*Data Entities & Attributes*) que se deben usar para extraer la información. Documenten las tablas involucradas y las relaciones entre ellas.
#
# ### 2.2 Bocetado Visual (Mockup)
# Diseñen la interfaz del *Dashboard* o reporte estructural donde se mostrarán los 3 KPIs.
# * Pueden utilizar **cualquier herramienta de dibujo o diseño** para generar este boceto (desde herramientas profesionales de prototipado, pasando por Canvas vectoriales, hasta el software básico **Paint**).
# * El boceto debe justificar la elección de la visualización (ej. gráficos de líneas para tendencias temporales, gráficos de barras para comparativas de categorías, o tarjetas numéricas de alto impacto para valores acumulados).

# %% [markdown]
# [Aquí cada grupo debe completar el diseño lógico y visual.]

# %% [markdown]
# ## 3: Construcción e Implementación de los KPIs
#
# ### Instrucciones Técnicas:
# 1. **Conexión al Repositorio:** El MIS que estamos construyendo no debe tener el mismo repositorio Git que el TPS. El MIS debe poder tener acceso a la base de datos o dataset de transacciones de su TPS.
# 2. **Procesamiento de Datos:** Utilicen las librerías de análisis de datos (como `pandas`) para cargar los datos crudos, realizar las uniones (*joins*), agrupaciones (*groupby*) y cálculos requeridos por las reglas de negocio de sus 3 KPIs.
# 3. **Generación de las Visualizaciones:** Programen la capa gráfica de su MIS (utilizando librerías como `matplotlib`, o `seaborn`). Asegúrense de que los gráficos sean limpios, estén correctamente etiquetados (ejes, títulos, leyendas) y correspondan fielmente a los mockups diseñados en el Paso 2.

# %% [markdown]
# [Aquí cada grupo añade bloques de código debajo de esta celda para realizar la implementación técnica.]

# %%
#Este grupo ha decidido montar una Base de Datos SQL para el almacenamiento de informacion. Para ello, se procede a implementar lo siguiente: 
#(este cuaderno de jupyter ha sido editado desde un entorno WSL2 - Ubuntu v24)

#P1: Definir las librerias y variables necesarias: 

from sqlalchemy import create_engine #necesaria para conectarse con la base de datos
import pandas as pd #uso de pandas para el manejo de las tablas

engine = create_engine("postgresql://biblioteca_isid223:223@localhost:5432/biblioteca") #link a la biblioteca (la password esta expuesta por motivos academicos

# %%
# Un chequeo breve de las distintas tablas
df_lib = pd.read_sql("SELECT * FROM libros LIMIT 5;", engine)
df_usr = pd.read_sql("SELECT * FROM personas LIMIT 5;", engine)
df_len = pd.read_sql("SELECT * FROM prestamos LIMIT 5;", engine)
print(df_lib)
# Out:
#    id_libro          isbn                          titulo          autor  \
# 0         1  978000000001  Introducción a la Programación     Juan Pérez
# 1         2  978000000002            Estructuras de Datos    María Gómez
# 2         3  978000000003     Bases de Datos Relacionales   Carlos López
# 3         4  978000000004          Ingeniería de Software     Ana Torres
# 4         5  978000000005           Redes de Computadoras  Luis Martínez
#
#          editorial  anio       categoria  cantidad_total  cantidad_disponible  \
# 0   Editorial Alfa  2018     Informática              10                    7
# 1   Editorial Beta  2019     Informática               8                    5
# 2  Editorial Gamma  2020  Bases de Datos              12                   10
# 3  Editorial Delta  2017        Software               6                    4
# 4  Editorial Omega  2016           Redes               9                    6
#
#     ubicacion  activo
# 0  Estante A1    True
# 1  Estante A2    True
# 2  Estante B1    True
# 3  Estante B2    True
# 4  Estante C1    True

# %%
print(df_usr)
# Out:
#    id_persona      cedula     nombre  apellido  \
# 0           1  1400721199        Ana    Medina
# 1           2  1706639422       José  González
# 2           3  1598058121  Alejandra     Reyes
# 3           4  1391932454       Rosa    Moreno
# 4           5  1161861139    Ernesto    García
#
#                                    email                direccion        tipo  \
# 0       ana.medina654@universidad.edu.ec         Calle Espejo 258       admin
# 1    josé.gonzález952@universidad.edu.ec         Calle Olmedo 987  estudiante
# 2  alejandra.reyes418@universidad.edu.ec         Av. Amazonas 123     docente
# 3      rosa.moreno578@universidad.edu.ec  Av. Naciones Unidas 369  estudiante
# 4   ernesto.garcía495@universidad.edu.ec        Av. República 654       admin
#
#         usuario                                         contrasena  activo
# 0    amedina782  $2b$12$OaGzbSHrFRA6l4GoMpvXe7CpRsZe9ObzxDNRf0N...    True
# 1  jgonzález970  $2b$12$amiYY5sIJ0PHxTXQeUvgoeLMK8uNWBoIxlKxVsp...    True
# 2     areyes205  $2b$12$fILW1azWSI9pGQkqqjkrsWw6SEMCiay0x1BAZOK...    True
# 3    rmoreno304  $2b$12$lVbT6mXZe0XPispjAxBLKH51zc8RYK4gpPkLINO...    True
# 4    egarcía207  $2b$12$z7h6itCmDDBRtsYh0OPk9pkjI7ozlNAbMmKyRmU...    True

# %%
print(df_len)
# Out:
#    id_prestamo fecha_prestamo fecha_devolucion_esperada fecha_devolucion_real  \
# 0            1     2024-05-01                2024-05-24                  None
# 1            2     2024-05-01                2024-05-18            2024-05-15
# 2            3     2024-05-01                2024-05-08            2024-05-06
# 3            4     2024-05-01                2024-05-25            2024-05-21
# 4            5     2024-05-01                2024-05-22            2024-05-18
#
#      estado  id_usuario  id_libro
# 0   vencido          35        85
# 1  devuelto         122         6
# 2  devuelto         121        35
# 3  devuelto          52        49
# 4  devuelto          16       320

# %% [markdown]
# ## 4: Validación de Atributos de Información e Interpretación Gerencial
#
# Para consolidar el taller, el equipo evaluará de forma analítica los resultados obtenidos antes de la entrega final.
#
# ### 4.1 Matriz de Atributos de Valor
# Verifiquen de manera crítica si la información que genera su celda de código cumple con las siguientes características esenciales:
# * **Simplicidad:** ¿El gráfico evita la sobrecarga de información y destaca lo realmente importante?
# * **Oportunidad (*Timeliness*):** ¿La consulta procesa los datos con la velocidad requerida para que el administrador actúe a tiempo?
# * **Accesibilidad:** ¿El formato del reporte permite que un usuario no técnico interprete el resultado de un solo vistazo?
#
# ### 4.2 Documentación de Interpretación Gerencial
# Para cada uno de los 3 KPIs implementados, redacten un párrafo analítico en formato de Markdown que responda a la siguiente estructura:
# > *"Si este indicador clave de rendimiento muestra un comportamiento [positivo/negativo/fuera de umbral], la acción correctiva o estratégica que la gerencia debe ejecutar de inmediato es..."*

# %% [markdown]
# [Aquí cada grupo debe indicar la Matriz de Atributos de Valor]

# %% [markdown]
# [Aquí cada grupo debe incluir la Documentación de Interpretación Gerencial]
